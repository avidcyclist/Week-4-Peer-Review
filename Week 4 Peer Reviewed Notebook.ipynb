# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Mitchell Osnowitz__
#
# I am currently an athletics coach, and studying taking this course for the future.

# %% [markdown]
# *I am interested in data science because I am curious about to problem solving.  I want to know why companies make the choices they do, and to personally be able to look at data so I can make decisions in my personal life. Whether it be sourcing information on sports, looking for a bargain online, or researching projects for fun.*

# %% [markdown]
# ### The next cell says hello to a friend

# %%
print("Hello Friend")
# Out:
# Hello Friend

# %% [markdown]
# | Here| is | my  | table |
# | :---: |---:| :---:|:---:|
# | How| does | it | look |
#
#
#
# > Blockdown quotes,
# > these will be on the same line
#
#
# ~~Stirke me up~~
#
# 1. Numbering
# 2. My
# 3. List
#
# ***Horizontal Lines***
#
# - Practicing
# - my bullet
# - lists and stuff
